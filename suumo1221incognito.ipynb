# %%
import requests
from bs4 import BeautifulSoup
from retry import retry
import time
import urllib.parse
import numpy as np
import pandas as pd

@retry(tries=3, delay=10, backoff=2)
def load_page(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    return soup

def scrape_suumo(url, max_page):
    data_samples = []
    times = []

    start = time.time()

    for page in range(1, max_page + 1):
        before = time.time()

        soup = load_page(url.format(page))
        building_list = soup.find_all(class_='cassetteitem')

        for building in building_list:
            building_data = extract_building_data(building)
            data_samples += extract_room_data(building, building_data, url)

        time.sleep(1)
        after = time.time()

        print_progress(page, max_page, before, after, data_samples, times)

    finish = time.time()
    print('総経過時間：', finish - start)

    return data_samples

def extract_building_data(building):
    building_info = []
    building_info.append(building.find(class_='ui-pct ui-pct--util1').text)
    building_info.append(building.find(class_='cassetteitem_content-title').text)
    building_info.append(building.find(class_='cassetteitem_detail-col1').text)

    details = building.find(class_='cassetteitem_detail-col2')
    for detail in details.find_all(class_='cassetteitem_detail-text'):
        building_info.append(detail.text)

    details = building.find(class_='cassetteitem_detail-col3')
    for detail in details.find_all('div'):
        building_info.append(detail.text)

    return building_info

def extract_room_data(building, building_info, url):
    room_data_samples = []
    rooms = building.find(class_='cassetteitem_other')

    for room in rooms.find_all(class_='js-cassette_link'):
        room_data = extract_single_room_data(room, url)
        room_data_samples.append(building_info + room_data)

    return room_data_samples

def extract_single_room_data(room, url):
    room_info = []

    for id_, detail in enumerate(room.find_all('td')):
        if id_ == 2:
            room_info.append(detail.text.strip())
        elif id_ == 3:
            room_info.append(detail.find(class_='cassetteitem_other-emphasis ui-text--bold').text)
            room_info.append(detail.find(class_='cassetteitem_price cassetteitem_price--administration').text)
        elif id_ == 4:
            room_info.append(detail.find(class_='cassetteitem_price cassetteitem_price--deposit').text)
            room_info.append(detail.find(class_='cassetteitem_price cassetteitem_price--gratuity').text)
        elif id_ == 5:
            room_info.append(detail.find(class_='cassetteitem_madori').text)
            room_info.append(detail.find(class_='cassetteitem_menseki').text)
        elif id_ == 8:
            get_url = detail.find(class_='js-cassette_link_href cassetteitem_other-linktext').get('href')
            abs_url = urllib.parse.urljoin(url, get_url)
            room_info.append(abs_url)

    return room_info

def print_progress(page, max_page, before, after, data_samples, times):
    running_time = after - before
    times.append(running_time)
    print(f'{page}ページ目：{running_time}秒')
    print(f'総取得件数：{len(data_samples)}')
    complete_ratio = round(page / max_page * 100, 3)
    print(f'完了：{complete_ratio}%')
    running_mean = np.mean(times)
    running_required_time = running_mean * (max_page - page)
    print(f'残り時間：{int(running_required_time / 3600)}時間{int((running_required_time % 3600) / 60)}分{int(running_required_time % 60)}秒\n')


# スクレイピング実行
url = 'https://suumo.jp/chintai/kanagawa/sc_yokohamashitsurumi/?page={}'
max_page = 155
data_samples = scrape_suumo(url, max_page)

# Pandas DataFrameに変換
correct_column_names = ['カテゴリ', '建物名', '住所', 'アクセス1', 'アクセス2', 'アクセス3', '築年数', '構造', '階数', '家賃', '管理費', '敷金', '礼金', '間取り', '面積', 'URL']
df = pd.DataFrame(data_samples, columns=correct_column_names)


#####ここまでスクレイピング
#####ここからクレンジング
# アクセス情報の処理と挿入
access_columns = ['アクセス1', 'アクセス2', 'アクセス3']
for col in access_columns:
    index = df.columns.get_loc(col)
    df[col + '_路線名'] = df[col].str.split('/', expand=True)[0]
    df[col + '_駅名'] = df[col].str.split('/', expand=True)[1].str.split(' 歩', expand=True)[0]
    df[col + '_徒歩分数'] = df[col].str.split('/', expand=True)[1].str.split(' 歩', expand=True)[1].str.replace('分', '', regex=True)
    df[col + '_徒歩分数'] = pd.to_numeric(df[col + '_徒歩分数'], errors='coerce')
    df.drop(col, axis=1, inplace=True)
    df.insert(index, col + '_路線名', df.pop(col + '_路線名'))
    df.insert(index + 1, col + '_駅名', df.pop(col + '_駅名'))
    df.insert(index + 2, col + '_徒歩分数', df.pop(col + '_徒歩分数'))


# 「家賃」、「敷金」、「礼金」の「-」を「0」に置換し、不要な文字列を除去して数値に変換
columns_to_convert = ['家賃', '敷金', '礼金']
for column in columns_to_convert:
    df[column] = df[column].replace('-', '0')
    df[column] = df[column].replace('万円', '', regex=True)
    df[column] = pd.to_numeric(df[column], errors='coerce') * 10000


# 「管理費」列の「-」を「0」に置換し、不要な文字列を除去して数値に変換
df['管理費'] = df['管理費'].replace('-', '0')
df['管理費'] = df['管理費'].replace('円', '', regex=True)
df['管理費'] = pd.to_numeric(df['管理費'], errors='coerce')


# 「面積」列の単位を除去し、数値に変換
df['面積'] = df['面積'].replace('m2', '', regex=True)
df['面積'] = pd.to_numeric(df['面積'], errors='coerce')



# 「築年数」列の処理
df['築年数'] = df['築年数'].replace('新築', '0')  # 「新築」を「0」に置き換え
df['築年数'] = df['築年数'].str.extract('(\d+)').astype(float)  # 数字の抽出と数値化




# すべての列が完全に一致する行の重複を削除
df = df.drop_duplicates()
# Out:
# 1ページ目：2.4162700176239014秒
# 総取得件数：50
# 完了：0.645%
# 残り時間：0時間6分12秒
#
# 2ページ目：2.2621660232543945秒
# 総取得件数：86
# 完了：1.29%
# 残り時間：0時間5分57秒
#
# 3ページ目：2.344654083251953秒
# 総取得件数：180
# 完了：1.935%
# 残り時間：0時間5分55秒
#
# 4ページ目：2.043109893798828秒
# 総取得件数：274
# 完了：2.581%
# 残り時間：0時間5分42秒
#
# 5ページ目：1.7077760696411133秒
# 総取得件数：313
# 完了：3.226%
# 残り時間：0時間5分23秒
#
# 6ページ目：1.8562531471252441秒
# 総取得件数：358
# 完了：3.871%
# 残り時間：0時間5分13秒
#
# 7ページ目：1.7844841480255127秒
# 総取得件数：398
# 完了：4.516%
# 残り時間：0時間5分4秒
#
# 8ページ目：1.942406177520752秒
# 総取得件数：454
# 完了：5.161%
# 残り時間：0時間5分0秒
#
# 9ページ目：1.921475887298584秒
# 総取得件数：510
# 完了：5.806%
# 残り時間：0時間4分56秒
#
# 10ページ目：1.7686030864715576秒
# 総取得件数：549
# 完了：6.452%
# 残り時間：0時間4分50秒
#
# 11ページ目：1.7863118648529053秒
# 総取得件数：607
# 完了：7.097%
# 残り時間：0時間4分45秒
#
# 12ページ目：2.222113847732544秒
# 総取得件数：672
# 完了：7.742%
# 残り時間：0時間4分46秒
#
# 13ページ目：2.299595832824707秒
# 総取得件数：720
# 完了：8.387%
# 残り時間：0時間4分47秒
#
# 14ページ目：1.7778820991516113秒
# 総取得件数：767
# 完了：9.032%
# 残り時間：0時間4分43秒
#
# 15ページ目：1.752959966659546秒
# 総取得件数：818
# 完了：9.677%
# 残り時間：0時間4分38秒
#
# 16ページ目：2.106671094894409秒
# 総取得件数：863
# 完了：10.323%
# 残り時間：0時間4分37秒
#
# 17ページ目：1.8712718486785889秒
# 総取得件数：914
# 完了：10.968%
# 残り時間：0時間4分34秒
#
# 18ページ目：1.8393800258636475秒
# 総取得件数：971
# 完了：11.613%
# 残り時間：0時間4分31秒
#
# 19ページ目：1.947770118713379秒
# 総取得件数：1001
# 完了：12.258%
# 残り時間：0時間4分29秒
#
# 20ページ目：1.7509009838104248秒
# 総取得件数：1051
# 完了：12.903%
# 残り時間：0時間4分25秒
#
# 21ページ目：2.476417064666748秒
# 総取得件数：1206
# 完了：13.548%
# 残り時間：0時間4分27秒
#
# 22ページ目：1.7240760326385498秒
# 総取得件数：1240
# 完了：14.194%
# 残り時間：0時間4分23秒
#
# 23ページ目：2.029498815536499秒
# 総取得件数：1272
# 完了：14.839%
# 残り時間：0時間4分21秒
#
# 24ページ目：1.88291597366333秒
# 総取得件数：1335
# 完了：15.484%
# 残り時間：0時間4分19秒
#
# 25ページ目：1.7742021083831787秒
# 総取得件数：1377
# 完了：16.129%
# 残り時間：0時間4分16秒
#
# 26ページ目：1.7698020935058594秒
# 総取得件数：1409
# 完了：16.774%
# 残り時間：0時間4分13秒
#
# 27ページ目：1.797837257385254秒
# 総取得件数：1461
# 完了：17.419%
# 残り時間：0時間4分10秒
#
# 28ページ目：1.7559051513671875秒
# 総取得件数：1502
# 完了：18.065%
# 残り時間：0時間4分7秒
#
# 29ページ目：1.9803540706634521秒
# 総取得件数：1539
# 完了：18.71%
# 残り時間：0時間4分5秒
#
# 30ページ目：1.9087600708007812秒
# 総取得件数：1567
# 完了：19.355%
# 残り時間：0時間4分3秒
#
# 31ページ目：1.9965567588806152秒
# 総取得件数：1606
# 完了：20.0%
# 残り時間：0時間4分1秒
#
# 32ページ目：2.385478973388672秒
# 総取得件数：1681
# 完了：20.645%
# 残り時間：0時間4分1秒
#
# 33ページ目：1.7172939777374268秒
# 総取得件数：1714
# 完了：21.29%
# 残り時間：0時間3分58秒
#
# 34ページ目：1.836709976196289秒
# 総取得件数：1760
# 完了：21.935%
# 残り時間：0時間3分56秒
#
# 35ページ目：1.772024154663086秒
# 総取得件数：1793
# 完了：22.581%
# 残り時間：0時間3分53秒
#
# 36ページ目：1.639449119567871秒
# 総取得件数：1821
# 完了：23.226%
# 残り時間：0時間3分50秒
#
# 37ページ目：1.69777512550354秒
# 総取得件数：1852
# 完了：23.871%
# 残り時間：0時間3分48秒
#
# 38ページ目：1.938788890838623秒
# 総取得件数：1883
# 完了：24.516%
# 残り時間：0時間3分46秒
#
# 39ページ目：1.8245151042938232秒
# 総取得件数：1917
# 完了：25.161%
# 残り時間：0時間3分44秒
#
# 40ページ目：1.7648520469665527秒
# 総取得件数：1961
# 完了：25.806%
# 残り時間：0時間3分41秒
#
# 41ページ目：1.9796171188354492秒
# 総取得件数：2009
# 完了：26.452%
# 残り時間：0時間3分39秒
#
# 42ページ目：1.6881589889526367秒
# 総取得件数：2050
# 完了：27.097%
# 残り時間：0時間3分37秒
#
# 43ページ目：1.7944488525390625秒
# 総取得件数：2098
# 完了：27.742%
# 残り時間：0時間3分34秒
#
# 44ページ目：1.940742015838623秒
# 総取得件数：2170
# 完了：28.387%
# 残り時間：0時間3分33秒
#
# 45ページ目：2.0160369873046875秒
# 総取得件数：2220
# 完了：29.032%
# 残り時間：0時間3分31秒
#
# 46ページ目：1.8347570896148682秒
# 総取得件数：2258
# 完了：29.677%
# 残り時間：0時間3分29秒
#
# 47ページ目：1.695906162261963秒
# 総取得件数：2298
# 完了：30.323%
# 残り時間：0時間3分26秒
#
# 48ページ目：1.8394858837127686秒
# 総取得件数：2348
# 完了：30.968%
# 残り時間：0時間3分24秒
#
# 49ページ目：1.8042888641357422秒
# 総取得件数：2387
# 完了：31.613%
# 残り時間：0時間3分22秒
#
# 50ページ目：1.6764302253723145秒
# 総取得件数：2429
# 完了：32.258%
# 残り時間：0時間3分20秒
#
# 51ページ目：1.722344160079956秒
# 総取得件数：2469
# 完了：32.903%
# 残り時間：0時間3分17秒
#
# 52ページ目：1.672658920288086秒
# 総取得件数：2502
# 完了：33.548%
# 残り時間：0時間3分15秒
#
# 53ページ目：1.9272351264953613秒
# 総取得件数：2563
# 完了：34.194%
# 残り時間：0時間3分13秒
#
# 54ページ目：2.1168880462646484秒
# 総取得件数：2600
# 完了：34.839%
# 残り時間：0時間3分12秒
#
# 55ページ目：2.257049083709717秒
# 総取得件数：2656
# 完了：35.484%
# 残り時間：0時間3分10秒
#
# 56ページ目：2.074655055999756秒
# 総取得件数：2706
# 完了：36.129%
# 残り時間：0時間3分9秒
#
# 57ページ目：1.775151014328003秒
# 総取得件数：2737
# 完了：36.774%
# 残り時間：0時間3分7秒
#
# 58ページ目：1.7469077110290527秒
# 総取得件数：2781
# 完了：37.419%
# 残り時間：0時間3分5秒
#
# 59ページ目：1.6604087352752686秒
# 総取得件数：2812
# 完了：38.065%
# 残り時間：0時間3分2秒
#
# 60ページ目：1.728140115737915秒
# 総取得件数：2856
# 完了：38.71%
# 残り時間：0時間3分0秒
#
# 61ページ目：1.9940581321716309秒
# 総取得件数：2902
# 完了：39.355%
# 残り時間：0時間2分58秒
#
# 62ページ目：1.806603193283081秒
# 総取得件数：2958
# 完了：40.0%
# 残り時間：0時間2分56秒
#
# 63ページ目：1.7235331535339355秒
# 総取得件数：2993
# 完了：40.645%
# 残り時間：0時間2分54秒
#
# 64ページ目：1.8228812217712402秒
# 総取得件数：3039
# 完了：41.29%
# 残り時間：0時間2分52秒
#
# 65ページ目：1.7416999340057373秒
# 総取得件数：3070
# 完了：41.935%
# 残り時間：0時間2分50秒
#
# 66ページ目：1.712062120437622秒
# 総取得件数：3105
# 完了：42.581%
# 残り時間：0時間2分48秒
#
# 67ページ目：1.7802610397338867秒
# 総取得件数：3130
# 完了：43.226%
# 残り時間：0時間2分46秒
#
# 68ページ目：1.8572897911071777秒
# 総取得件数：3159
# 完了：43.871%
# 残り時間：0時間2分44秒
#
# 69ページ目：1.782677173614502秒
# 総取得件数：3184
# 完了：44.516%
# 残り時間：0時間2分42秒
#
# 70ページ目：1.77848219871521秒
# 総取得件数：3206
# 完了：45.161%
# 残り時間：0時間2分40秒
#
# 71ページ目：1.7482471466064453秒
# 総取得件数：3234
# 完了：45.806%
# 残り時間：0時間2分38秒
#
# 72ページ目：1.6603248119354248秒
# 総取得件数：3260
# 完了：46.452%
# 残り時間：0時間2分36秒
#
# 73ページ目：1.8303749561309814秒
# 総取得件数：3307
# 完了：47.097%
# 残り時間：0時間2分34秒
#
# 74ページ目：1.7225589752197266秒
# 総取得件数：3335
# 完了：47.742%
# 残り時間：0時間2分32秒
#
# 75ページ目：1.8673920631408691秒
# 総取得件数：3360
# 完了：48.387%
# 残り時間：0時間2分30秒
#
# 76ページ目：1.8345410823822021秒
# 総取得件数：3402
# 完了：49.032%
# 残り時間：0時間2分28秒
#
# 77ページ目：1.8950238227844238秒
# 総取得件数：3430
# 完了：49.677%
# 残り時間：0時間2分26秒
#
# 78ページ目：1.6896929740905762秒
# 総取得件数：3461
# 完了：50.323%
# 残り時間：0時間2分24秒
#
# 79ページ目：1.7288248538970947秒
# 総取得件数：3491
# 完了：50.968%
# 残り時間：0時間2分22秒
#
# 80ページ目：1.7036700248718262秒
# 総取得件数：3522
# 完了：51.613%
# 残り時間：0時間2分20秒
#
# 81ページ目：1.72499680519104秒
# 総取得件数：3564
# 完了：52.258%
# 残り時間：0時間2分18秒
#
# 82ページ目：1.6761178970336914秒
# 総取得件数：3594
# 完了：52.903%
# 残り時間：0時間2分16秒
#
# 83ページ目：1.7210109233856201秒
# 総取得件数：3624
# 完了：53.548%
# 残り時間：0時間2分14秒
#
# 84ページ目：1.6950840950012207秒
# 総取得件数：3649
# 完了：54.194%
# 残り時間：0時間2分12秒
#
# 85ページ目：2.0743377208709717秒
# 総取得件数：3688
# 完了：54.839%
# 残り時間：0時間2分10秒
#
# 86ページ目：2.0054750442504883秒
# 総取得件数：3716
# 完了：55.484%
# 残り時間：0時間2分8秒
#
# 87ページ目：1.7188498973846436秒
# 総取得件数：3740
# 完了：56.129%
# 残り時間：0時間2分6秒
#
# 88ページ目：1.6743521690368652秒
# 総取得件数：3767
# 完了：56.774%
# 残り時間：0時間2分4秒
#
# 89ページ目：1.7084579467773438秒
# 総取得件数：3794
# 完了：57.419%
# 残り時間：0時間2分2秒
#
# 90ページ目：1.7824561595916748秒
# 総取得件数：3822
# 完了：58.065%
# 残り時間：0時間2分0秒
#
# 91ページ目：1.697472095489502秒
# 総取得件数：3849
# 完了：58.71%
# 残り時間：0時間1分58秒
#
# 92ページ目：2.052309989929199秒
# 総取得件数：3879
# 完了：59.355%
# 残り時間：0時間1分57秒
#
# 93ページ目：2.0880701541900635秒
# 総取得件数：3909
# 完了：60.0%
# 残り時間：0時間1分55秒
#
# 94ページ目：1.6619110107421875秒
# 総取得件数：3933
# 完了：60.645%
# 残り時間：0時間1分53秒
#
# 95ページ目：1.6673219203948975秒
# 総取得件数：3959
# 完了：61.29%
# 残り時間：0時間1分51秒
#
# 96ページ目：1.7803828716278076秒
# 総取得件数：3997
# 完了：61.935%
# 残り時間：0時間1分49秒
#
# 97ページ目：1.715054988861084秒
# 総取得件数：4022
# 完了：62.581%
# 残り時間：0時間1分47秒
#
# 98ページ目：2.3293192386627197秒
# 総取得件数：4044
# 完了：63.226%
# 残り時間：0時間1分46秒
#
# 99ページ目：2.2417030334472656秒
# 総取得件数：4073
# 完了：63.871%
# 残り時間：0時間1分44秒
#
# 100ページ目：1.8079969882965088秒
# 総取得件数：4108
# 完了：64.516%
# 残り時間：0時間1分42秒
#
# 101ページ目：1.8024539947509766秒
# 総取得件数：4135
# 完了：65.161%
# 残り時間：0時間1分40秒
#
# 102ページ目：1.7746789455413818秒
# 総取得件数：4168
# 完了：65.806%
# 残り時間：0時間1分38秒
#
# 103ページ目：1.6701288223266602秒
# 総取得件数：4199
# 完了：66.452%
# 残り時間：0時間1分36秒
#
# 104ページ目：1.7702739238739014秒
# 総取得件数：4222
# 完了：67.097%
# 残り時間：0時間1分34秒
#
# 105ページ目：1.7842919826507568秒
# 総取得件数：4252
# 完了：67.742%
# 残り時間：0時間1分33秒
#
# 106ページ目：1.7134451866149902秒
# 総取得件数：4281
# 完了：68.387%
# 残り時間：0時間1分31秒
#
# 107ページ目：1.9561331272125244秒
# 総取得件数：4305
# 完了：69.032%
# 残り時間：0時間1分29秒
#
# 108ページ目：1.8522937297821045秒
# 総取得件数：4331
# 完了：69.677%
# 残り時間：0時間1分27秒
#
# 109ページ目：1.7109732627868652秒
# 総取得件数：4362
# 完了：70.323%
# 残り時間：0時間1分25秒
#
# 110ページ目：1.7397139072418213秒
# 総取得件数：4393
# 完了：70.968%
# 残り時間：0時間1分23秒
#
# 111ページ目：1.8545050621032715秒
# 総取得件数：4420
# 完了：71.613%
# 残り時間：0時間1分21秒
#
# 112ページ目：1.6985499858856201秒
# 総取得件数：4470
# 完了：72.258%
# 残り時間：0時間1分19秒
#
# 113ページ目：2.015378952026367秒
# 総取得件数：4496
# 完了：72.903%
# 残り時間：0時間1分18秒
#
# 114ページ目：1.7044761180877686秒
# 総取得件数：4519
# 完了：73.548%
# 残り時間：0時間1分16秒
#
# 115ページ目：2.041799783706665秒
# 総取得件数：4546
# 完了：74.194%
# 残り時間：0時間1分14秒
#
# 116ページ目：2.0581328868865967秒
# 総取得件数：4578
# 完了：74.839%
# 残り時間：0時間1分12秒
#
# 117ページ目：1.7522528171539307秒
# 総取得件数：4611
# 完了：75.484%
# 残り時間：0時間1分10秒
#
# 118ページ目：1.7375431060791016秒
# 総取得件数：4644
# 完了：76.129%
# 残り時間：0時間1分8秒
#
# 119ページ目：1.7153658866882324秒
# 総取得件数：4671
# 完了：76.774%
# 残り時間：0時間1分6秒
#
# 120ページ目：1.7826929092407227秒
# 総取得件数：4693
# 完了：77.419%
# 残り時間：0時間1分4秒
#
# 121ページ目：1.7053859233856201秒
# 総取得件数：4719
# 完了：78.065%
# 残り時間：0時間1分3秒
#
# 122ページ目：1.740049123764038秒
# 総取得件数：4747
# 完了：78.71%
# 残り時間：0時間1分1秒
#
# 123ページ目：2.0793442726135254秒
# 総取得件数：4774
# 完了：79.355%
# 残り時間：0時間0分59秒
#
# 124ページ目：1.9233407974243164秒
# 総取得件数：4813
# 完了：80.0%
# 残り時間：0時間0分57秒
#
# 125ページ目：1.6955921649932861秒
# 総取得件数：4841
# 完了：80.645%
# 残り時間：0時間0分55秒
#
# 126ページ目：1.8006489276885986秒
# 総取得件数：4872
# 完了：81.29%
# 残り時間：0時間0分53秒
#
# 127ページ目：2.1325879096984863秒
# 総取得件数：4896
# 完了：81.935%
# 残り時間：0時間0分51秒
#
# 128ページ目：1.673546314239502秒
# 総取得件数：4923
# 完了：82.581%
# 残り時間：0時間0分50秒
#
# 129ページ目：1.7282402515411377秒
# 総取得件数：4953
# 完了：83.226%
# 残り時間：0時間0分48秒
#
# 130ページ目：2.0872440338134766秒
# 総取得件数：4978
# 完了：83.871%
# 残り時間：0時間0分46秒
#
# 131ページ目：1.806041955947876秒
# 総取得件数：5001
# 完了：84.516%
# 残り時間：0時間0分44秒
#
# 132ページ目：1.6575651168823242秒
# 総取得件数：5025
# 完了：85.161%
# 残り時間：0時間0分42秒
#
# 133ページ目：1.687298059463501秒
# 総取得件数：5057
# 完了：85.806%
# 残り時間：0時間0分40秒
#
# 134ページ目：1.6464152336120605秒
# 総取得件数：5085
# 完了：86.452%
# 残り時間：0時間0分38秒
#
# 135ページ目：1.7209930419921875秒
# 総取得件数：5116
# 完了：87.097%
# 残り時間：0時間0分36秒
#
# 136ページ目：1.657731056213379秒
# 総取得件数：5144
# 完了：87.742%
# 残り時間：0時間0分35秒
#
# 137ページ目：1.6862897872924805秒
# 総取得件数：5172
# 完了：88.387%
# 残り時間：0時間0分33秒
#
# 138ページ目：1.9093382358551025秒
# 総取得件数：5202
# 完了：89.032%
# 残り時間：0時間0分31秒
#
# 139ページ目：2.0045828819274902秒
# 総取得件数：5229
# 完了：89.677%
# 残り時間：0時間0分29秒
#
# 140ページ目：1.6990370750427246秒
# 総取得件数：5254
# 完了：90.323%
# 残り時間：0時間0分27秒
#
# 141ページ目：1.793065071105957秒
# 総取得件数：5277
# 完了：90.968%
# 残り時間：0時間0分25秒
#
# 142ページ目：1.6707651615142822秒
# 総取得件数：5300
# 完了：91.613%
# 残り時間：0時間0分24秒
#
# 143ページ目：1.7214720249176025秒
# 総取得件数：5323
# 完了：92.258%
# 残り時間：0時間0分22秒
#
# 144ページ目：1.7775359153747559秒
# 総取得件数：5351
# 完了：92.903%
# 残り時間：0時間0分20秒
#
# 145ページ目：1.694568157196045秒
# 総取得件数：5372
# 完了：93.548%
# 残り時間：0時間0分18秒
#
# 146ページ目：1.7525911331176758秒
# 総取得件数：5397
# 完了：94.194%
# 残り時間：0時間0分16秒
#
# 147ページ目：2.116912841796875秒
# 総取得件数：5426
# 完了：94.839%
# 残り時間：0時間0分14秒
#
# 148ページ目：1.6731772422790527秒
# 総取得件数：5451
# 完了：95.484%
# 残り時間：0時間0分12秒
#
# 149ページ目：1.693161964416504秒
# 総取得件数：5475
# 完了：96.129%
# 残り時間：0時間0分11秒
#
# 150ページ目：1.730125904083252秒
# 総取得件数：5503
# 完了：96.774%
# 残り時間：0時間0分9秒
#
# 151ページ目：1.7464749813079834秒
# 総取得件数：5537
# 完了：97.419%
# 残り時間：0時間0分7秒
#
# 152ページ目：1.7870030403137207秒
# 総取得件数：5563
# 完了：98.065%
# 残り時間：0時間0分5秒
#
# 153ページ目：1.739837884902954秒
# 総取得件数：5589
# 完了：98.71%
# 残り時間：0時間0分3秒
#
# 154ページ目：1.879554033279419秒
# 総取得件数：5612
# 完了：99.355%
# 残り時間：0時間0分1秒
#
# 155ページ目：1.8041040897369385秒
# 総取得件数：5636
# 完了：100.0%
# 残り時間：0時間0分0秒
#
# 総経過時間： 285.3750898838043

# %%
print(df.columns)
# Out:
# Index(['カテゴリ', '建物名', '住所', 'アクセス1_路線名', 'アクセス1_駅名', 'アクセス1_徒歩分数', 'アクセス2_路線名',
#        'アクセス2_駅名', 'アクセス2_徒歩分数', 'アクセス3_路線名', 'アクセス3_駅名', 'アクセス3_徒歩分数', '築年数',
#        '構造', '階数', '家賃', '管理費', '敷金', '礼金', '間取り', '面積', 'URL'],
#       dtype='object')

# %%
# 処理後のデータフレームの先頭部分を表示して確認
print(df.head())
# Out:
#       カテゴリ                  建物名               住所 アクセス1_路線名 アクセス1_駅名  \
# 0   賃貸アパート          Puerta Rojo  神奈川県横浜市鶴見区市場西中町      京急本線    鶴見市場駅
# 1   賃貸アパート  京急本線 鶴見市場駅 2階建 築16年  神奈川県横浜市鶴見区市場西中町      京急本線    鶴見市場駅
# 2  賃貸マンション             IN　BLOOM   神奈川県横浜市鶴見区潮田町４     ＪＲ鶴見線      浅野駅
# 3  賃貸マンション    ＪＲ鶴見線 浅野駅 4階建 築8年   神奈川県横浜市鶴見区潮田町４     ＪＲ鶴見線      浅野駅
# 4   賃貸アパート          カーサフェリーチェ矢向    神奈川県横浜市鶴見区矢向３     ＪＲ南武線      尻手駅
#
#    アクセス1_徒歩分数 アクセス2_路線名 アクセス2_駅名  アクセス2_徒歩分数 アクセス3_路線名  ...   築年数   構造  階数  \
# 0           7      京急本線     八丁畷駅        14.0   ＪＲ京浜東北線  ...  16.0  2階建  1階
# 1           6     ＪＲ南武線     八丁畷駅        12.0   ＪＲ京浜東北線  ...  16.0  2階建  1階
# 2           9      京急本線    京急鶴見駅        21.0     ＪＲ鶴見線  ...   8.0  4階建  3階
# 3          10      京急本線    京急鶴見駅        22.0   ＪＲ京浜東北線  ...   8.0  4階建  3階
# 4           5   ＪＲ京浜東北線      川崎駅        20.0   ＪＲ京浜東北線  ...   5.0  3階建  2階
#
#         家賃   管理費       敷金        礼金   間取り     面積  \
# 0  92000.0  3000  92000.0   92000.0  1LDK  33.85
# 1  92000.0  3000  92000.0   92000.0  1LDK  35.00
# 2  94000.0  3500  94000.0  141000.0  1LDK  40.72
# 3  94000.0  3500  94000.0  141000.0  1LDK  40.72
# 4  71000.0  4000  71000.0   71000.0    1K  19.17
#
#                                                  URL
# 0  https://suumo.jp/chintai/jnc_000071012556/?bc=...
# 1  https://suumo.jp/chintai/jnc_000071066695/?bc=...
# 2  https://suumo.jp/chintai/jnc_000047219877/?bc=...
# 3  https://suumo.jp/chintai/jnc_000047219878/?bc=...
# 4  https://suumo.jp/chintai/jnc_000074296801/?bc=...
#
# [5 rows x 22 columns]

# %%
#スプシ

# %%
pip install gspread oauth2client
# Out:
# Collecting gspread
#   Obtaining dependency information for gspread from https://files.pythonhosted.org/packages/79/14/baddb424ffabc843d8b4776fbe4f840037fab100aa4e4a5e8cf5fbcafc8e/gspread-5.12.3-py3-none-any.whl.metadata
#   Downloading gspread-5.12.3-py3-none-any.whl.metadata (8.8 kB)
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 567.6 kB/s eta 0:00:00 0:00:01
# Collecting google-auth>=1.12.0 (from gspread)
#   Obtaining dependency information for google-auth>=1.12.0 from https://files.pythonhosted.org/packages/f4/d2/9f6f3b9c0fd486617816cff42e856afea079d0bad99f0e60dc186c76b881/google_auth-2.25.2-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.25.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib>=0.4.1 (from gspread)
#   Obtaining dependency information for google-auth-oauthlib>=0.4.1 from https://files.pythonhosted.org/packages/71/bf/9e125754d1adb3bc4bd206c4e5df756513b1d23675ac06caa471278d1f3f/google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting httplib2>=0.9.1 (from oauth2client)
#   Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Collecting pyasn1>=0.1.7 (from oauth2client)
#   Obtaining dependency information for pyasn1>=0.1.7 from https://files.pythonhosted.org/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting pyasn1-modules>=0.0.5 (from oauth2client)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting rsa>=3.1.4 (from oauth2client)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.6.1 in /Users/satoshitsuchida/Library/Python/3.11/lib/python/site-packages (from oauth2client) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.12.0->gspread)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib>=0.4.1->gspread)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httplib2>=0.9.1->oauth2client) (3.1.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: requests>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2023.7.22)
# Downloading gspread-5.12.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.6 MB/s eta 0:00:00
# Downloading google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 kB 9.1 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 17.0 MB/s eta 0:00:00
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Installing collected packages: pyasn1, oauthlib, httplib2, cachetools, rsa, requests-oauthlib, pyasn1-modules, oauth2client, google-auth, google-auth-oauthlib, gspread
# Successfully installed cachetools-5.3.2 google-auth-2.25.2 google-auth-oauthlib-1.2.0 gspread-5.12.3 httplib2-0.22.0 oauth2client-4.1.3 oauthlib-3.2.2 pyasn1-0.5.1 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

def save_to_google_sheets(df, spreadsheet_name, worksheet_name):
    scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
    creds = ServiceAccountCredentials.from_json_keyfile_name('クレデンシャルファイル.json', scope)
    client = gspread.authorize(creds)

    try:
        # スプレッドシートを開くか、存在しなければ新規作成
        sheet = client.open(spreadsheet_name).sheet1
    except gspread.SpreadsheetNotFound:
        sheet = client.create(spreadsheet_name).sheet1

    # ワークシートの名前を変更
    sheet.update_title(worksheet_name)

    # DataFrame内のNaN値を0に置換
    df.fillna(0, inplace=True)

    # DataFrame を Google スプレッドシートに書き込む
    # 名前付き引数を使用して更新されたメソッドの使用法に従って修正
    sheet.update(range_name='A1', values=[df.columns.values.tolist()] + df.values.tolist())

# スクレイピングしたデータをスプレッドシートに保存
# dfはあなたのDataFrame変数です。適切なDataFrameを渡してください。
save_to_google_sheets(df, 'suumo1221', 'Sheet1')
# Out:
# /var/folders/xt/62y82p1s2f19jxr5_mt6x3900000gn/T/ipykernel_27021/1701189344.py:24: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   sheet.update(range_name='A1', values=[df.columns.values.tolist()] + df.values.tolist())

# %%
pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Collecting google-api-python-client
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/62/1b/3ff6bd5f33c1a1780835725014ac480128d2d1e3244b2809275d0fa4f726/google_api_python_client-2.111.0-py2.py3-none-any.whl.metadata
#   Downloading google_api_python_client-2.111.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-auth-httplib2
#   Obtaining dependency information for google-auth-httplib2 from https://files.pythonhosted.org/packages/be/8a/fe34d2f3f9470a27b01c9e76226965863f153d5fbe276f83608562e49c04/google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: google-auth-oauthlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.2.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-api-python-client) (2.25.2)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/d6/c9/0462f037b62796fbda4801be62d0ae3147eaeb99e2939661580c98abe3eb/google_api_core-2.15.0-py3-none-any.whl.metadata
#   Downloading google_api_core-2.15.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth-oauthlib) (1.3.1)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for googleapis-common-protos<2.0.dev0,>=1.56.2 from https://files.pythonhosted.org/packages/f0/43/c9d8f75ddf08e2a0a27db243c13a700c3cc7ec615b545b697cf6f715ad92/googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Obtaining dependency information for protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 from https://files.pythonhosted.org/packages/e6/db/7b2edc72807d45d72f9db42f3eb86ddaf37f9e55d923159b1dbfc9d835bc/protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Downloading protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Downloading google_api_python_client-2.111.0-py2.py3-none-any.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 48.0 MB/s eta 0:00:0000:0100:01
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_api_core-2.15.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.0/122.0 kB 19.2 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 43.5 MB/s eta 0:00:00
# Downloading protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 53.5 MB/s eta 0:00:00
# Installing collected packages: uritemplate, protobuf, googleapis-common-protos, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed google-api-core-2.15.0 google-api-python-client-2.111.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.62.0 protobuf-4.25.1 uritemplate-4.1.1
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build
from google.oauth2.service_account import Credentials

def list_google_drive_files(service_account_file):
    # サービスアカウント認証情報の読み込み
    creds = Credentials.from_service_account_file(
        service_account_file,
        scopes=['https://www.googleapis.com/auth/drive']
    )

    service = build('drive', 'v3', credentials=creds)

    # Googleドライブ内のファイルリストを取得
    results = service.files().list(
        pageSize=10, fields="nextPageToken, files(id, name)"
    ).execute()
    items = results.get('files', [])

    if not items:
        print('No files found.')
    else:
        print('Files:')
        for item in items:
            print(f"{item['name']} ({item['id']})")

# サービスアカウントのJSONキーファイルを指定
service_account_file = 'クレデンシャルファイル.json'

list_google_drive_files(service_account_file)
# Out:
# Files:
# suumo1221 (1aAEDZjipNqKu5f3JbnPAnNCtK0GdSCgAUYMgYlyioas)
# suumo12210045 (16LWcb9cE9iFVuNADWHmYf23ZyhwfqdkUgCqNiiflF-Q)
# suumo12202145 (1v3jjF6Kn_G5kZtRAGSGXxuZFvMF--jdLBGjUbshYCro)
# My Spreadsheet (1U8t4PPv9aMKtvIN3EfwrJMEKqstBo_ivVAdR1_2QVUo)
# suumo_cleansing.csv (1dJU0ogxUHMYqYlIsoycqms9srmaLjTI8)

# %%
from googleapiclient.discovery import build
from google.oauth2.service_account import Credentials
import gspread

# サービスアカウントのクレデンシャルファイルのパスを設定
credentials_file_path = 'クレデンシャルファイル.json'

# クレデンシャルをロード
creds = Credentials.from_service_account_file(credentials_file_path)
scoped_creds = creds.with_scopes(['https://www.googleapis.com/auth/drive'])

# gspread を使用して認証
gc = gspread.authorize(scoped_creds)

# スプレッドシートを開く
spreadsheet_name = 'suumo1221'
spreadsheet = gc.open(spreadsheet_name)

# Google Drive サービスを取得
drive_service = build('drive', 'v3', credentials=scoped_creds)

# スプレッドシートのファイルIDを取得
spreadsheet_id = spreadsheet.id

# 「URLを知っている人はだれでも見れる」設定を適用
drive_service.permissions().create(
    fileId=spreadsheet_id,
    body={'type': 'anyone', 'role': 'reader'},
    fields='id'
).execute()

# スプレッドシートのウェブビューリンクを取得
web_view_link = f"https://docs.google.com/spreadsheets/d/{spreadsheet_id}/edit"

print(web_view_link)
# Out:
# https://docs.google.com/spreadsheets/d/1aAEDZjipNqKu5f3JbnPAnNCtK0GdSCgAUYMgYlyioas/edit

# %%
#スプレッドシートを呼び出し格納

import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

SP_CREDENTIAL_FILE = 'クレデンシャルファイル.json'
SP_COPE = [
    'https://www.googleapis.com/auth/drive',
    'https://spreadsheets.google.com/feeds'
]
SP_SHEET_KEY = '1aAEDZjipNqKu5f3JbnPAnNCtK0GdSCgAUYMgYlyioas'
SP_SHEET = 'Sheet1'

credentials = ServiceAccountCredentials.from_json_keyfile_name(SP_CREDENTIAL_FILE, SP_COPE)
gc = gspread.authorize(credentials)

sh = gc.open_by_key(SP_SHEET_KEY)
worksheet = sh.worksheet(SP_SHEET)
data = worksheet.get_all_values()
print(data)
# Out:
# [['カテゴリ', '建物名', '住所', 'アクセス1_路線名', 'アクセス1_駅名', 'アクセス1_徒歩分数', 'アクセス2_路線名', 'アクセス2_駅名', 'アクセス2_徒歩分数', 'アクセス3_路線名', 'アクセス3_駅名', 'アクセス3_徒歩分数', '築年数', '構造', '階数', '家賃', '管理費', '敷金', '礼金', '間取り', '面積', 'URL'], ['賃貸アパート', 'Puerta Rojo', '神奈川県横浜市鶴見区市場西中町', '京急本線', '鶴見市場駅', '7', '京急本線', '八丁畷駅', '14', 'ＪＲ京浜東北線', '鶴見駅', '17', '16', '2階建', '1階', '92000', '3000', '92000', '92000', '1LDK', '33.85', 'https://suumo.jp/chintai/jnc_000071012556/?bc=100358009319'], ['賃貸アパート', '京急本線 鶴見市場駅 2階建 築16年', '神奈川県横浜市鶴見区市場西中町', '京急本線', '鶴見市場駅', '6', 'ＪＲ南武線', '八丁畷駅', '12', 'ＪＲ京浜東北線', '鶴見駅', '18', '16', '2階建', '1階', '92000', '3000', '92000', '92000', '1LDK', '35', 'https://suumo.jp/chintai/jnc_000071066695/?bc=100358119591'], ['賃貸マンション', 'IN\u3000BLOOM', '神奈川県横浜市鶴見区潮田町４', 'ＪＲ鶴見線', '浅野駅', '9', '京急本線', '京急鶴見駅', '21', 'ＪＲ鶴見線', '安善駅', '12', '8', '4階建', '3階', '94000', '3500', '94000', '141000', '1LDK', '40.72', 'https://suumo.jp/chintai/jnc_000047219877/?bc=100358012395'], ['賃貸マンション', 'ＪＲ鶴見線 浅野駅 4階建 築8年', '神奈川県横浜市鶴見区潮田町４', 'ＪＲ鶴見線', '浅野駅', '10', '京急本線', '京急鶴見駅', '22', 'ＪＲ京浜東北線', '鶴見駅', '24', '8', '4階建', '3階', '94000', '3500', '94000', '141000', '1LDK', '40.72', 'https://suumo.jp/chintai/jnc_000047219878/?bc=100358029174'], ['賃貸アパート', 'カーサフェリーチェ矢向', '神奈川県横浜市鶴見区矢向３', 'ＪＲ南武線', '尻手駅', '5', 'ＪＲ京浜東北線', '川崎駅', '20', 'ＪＲ京浜東北線', '鶴見駅 バス21分 (バス停)矢向三丁目', '3', '5', '3階建', '2階', '71000', '4000', '71000', '71000', '1K', '19.17', 'https://suumo.jp/chintai/jnc_000074296801/?bc=100358024462'], ['賃貸アパート', 'ＪＲ南武線 尻手駅 3階建 築5年', '神奈川県横浜市鶴見区矢向３', 'ＪＲ南武線', '尻手駅', '5', 'ＪＲ南武線', '矢向駅', '12', 'ＪＲ京浜東北線', '川崎駅', '20', '5', '3階建', '2階', '71000', '4000', '71000', '71000', '1K', '19.17', 'https://suumo.jp/chintai/jnc_000074296802/?bc=100357997574'], ['賃貸マンション', 'スパシエソリデ横浜鶴見', '神奈川県横浜市鶴見区生麦４', '京急本線', '生麦駅', '6', '京急本線', '花月総持寺駅', '6', 'ＪＲ京浜東北線', '鶴見駅', '18', '8', '10階建', '7階', '77000', '9000', '77000', '77000', '1K', '23.44', 'https://suumo.jp/chintai/jnc_000087013526/?bc=100357270121'], ['賃貸マンション', 'スパシエソリデ横浜鶴見', '神奈川県横浜市鶴見区生麦４', '京急本線', '生麦駅', '6', '京急本線', '花月総持寺駅', '6', 'ＪＲ京浜東北線', '鶴見駅', '18', '8', '10階建', '3階', '71000', '15000', '0', '0', '1K', '23.44', 'https://suumo.jp/chintai/jnc_000046967292/?bc=100354700014'], ['賃貸マンション', 'スパシエソリデ横浜鶴見', '神奈川県横浜市鶴見区生麦４', '京急本線', '生麦駅', '6', '京急本線', '花月総持寺駅', '6', 'ＪＲ京浜東北線', '鶴見駅', '18', '8', '10階建', '10階', '79000', '8000', '0', '79000', '1K', '23.44', 'https://suumo.jp/chintai/jnc_000086635454/?bc=100354937779'], ['賃貸マンション', 'スパシエソリデ横浜鶴見', '神奈川県横浜市鶴見区生麦４', '京急本線', '生麦駅', '6', '京急本線', '花月総持寺駅', '6', 'ＪＲ京浜東北線', '鶴見駅', '18', '8', '10階建', '10階', '79000', '8000', '0', '79000', '1K', '23.44', 'https://suumo.jp/chintai/jnc_000058508241/?bc=100355937867'], ['賃貸マンション', 'スパシエソリデ横浜鶴見', '神奈川県横浜市鶴見区生麦４', '京急本線', '生麦駅', '6', '京急本線', '花月総持寺駅', '6', 'ＪＲ京浜東北線', '鶴見駅', '18', '8', '10階建', '3階', '74500', '13000', '0', '0', '1K', '23.4', 'https://suumo.jp/chintai/jnc_000086651717/?bc=100355224641'], ['賃貸マンション', 'アイル横浜ノースツインズI', '神奈川県横浜市鶴見区市場富士見町', '京急本線', '鶴見市場駅', '4', '京急本線', '八丁畷駅', '13', 'ＪＲ京浜東北線', '鶴見駅', '19', '6', '11階建', '1階', '69000', '13000', '0', '103500', '1K', '21.75', 'https://suumo.jp/chintai/jnc_000081970585/?bc=100345449630'], ['賃貸マンション', 'アイル横浜ノースツインズI', '神奈川県横浜市鶴見区市場富士見町', '京急本線', '鶴見市場駅', '4', '京急本線', '八丁畷駅', '13', 'ＪＲ京浜東北線', '鶴見駅', '19', '6', '11階建', '9階', '74000', '8000', '0', '74000', '1K', '21.75', 'https://suumo.jp/chintai/jnc_000063038022/?bc=100358125432'], ['賃貸マンション', 'アイル横浜ノースツインズI', '神奈川県横浜市鶴見区市場富士見町', '京急本線', '鶴見市場駅', '4', '京急本線', '八丁畷駅', '13', 'ＪＲ京浜東北線', '鶴見駅', '19', '6', '11階建', '8階', '75000', '8000', '0', '75000', '1K', '21.7', 'https://suumo.jp/chintai/jnc_000086417133/?bc=100353270345'], ['賃貸マンション', 'アイル横浜ノースツインズI', '神奈川県横浜市鶴見区市場富士見町', '京急本線', '鶴見市場駅', '4', '京急本線', '八丁畷駅', '13', 'ＪＲ京浜東北線', '鶴見駅', '19', '6', '11階建', '4階', '76000', '8000', '0', '76000', '1K', '21.75', 'https://suumo.jp/chintai/jnc_000062053464/?bc=100357017526'], ['賃貸マンション', 'アイル横浜ノースツインズI', '神奈川県横浜市鶴見区市場富士見町', '京急本線', '鶴見市場駅', '4', '京急本線', '八丁畷駅', '13', 'ＪＲ京浜東北線', '鶴見駅', '1 ...

# %%
import pandas as pd

# データをDataFrameに変換
df = pd.DataFrame(data)

# CSVファイルに保存
df.to_csv('suumo1221.csv', index=False, encoding='utf-8-sig')
